# %%
# === 1️⃣ Mount Drive (optional, skip if files already in /content) ===
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/dynamic_games_RL
# Out:
# /content/dynamic_games_RL

# %%
# Step 2: Configure Git
# !git config --global user.name 'namwook0921'
# !git config --global user.email 'namwook0921@gmail.com'

# %%
import getpass

# === 4️⃣ Configure your GitHub repo credentials ===
# Replace the variables below with your own info
GITHUB_USERNAME = "namwook0921"
GITHUB_EMAIL = "namwook0921@gmail.com"
GITHUB_TOKEN = getpass.getpass("Please enter your GitHub personal access token: ")   # from https://github.com/settings/tokens
REPO_NAME = "dynamic-games-RL"

# !rsync -av --exclude='*.gdoc' --exclude='*.png' /content/drive/MyDrive/dynamic_games_RL/ /content/dynamic_games_RL/

# === 5️⃣ Initialize git (skip if already a repo) ===
# !git clone https://github.com/namwook0921/{REPO_NAME}.git /content/dynamic_games_RL

# === 6️⃣ Add all files, commit, and connect to remote ===
# !git add .
# !git commit -m "Upload all files from Colab"
# !git config pull.rebase false
# !git pull origin main --allow-unrelated-histories
# !git push https://{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git
# Out:
# Please enter your GitHub personal access token: ··········
# sending incremental file list
# Untitled0.ipynb
# .git/
# .git/COMMIT_EDITMSG
# .git/config
# .git/index
# .git/logs/HEAD
# .git/logs/refs/heads/main
# .git/objects/
# .git/objects/03/6f7206723763ad28624b1731ff02aa88f69f93
# .git/objects/25/59fdc4b014628543363dc4877536eeb7d2a848
# .git/refs/heads/
# .git/refs/heads/main
#
# sent 6,742,444 bytes  received 250 bytes  4,495,129.33 bytes/sec
# total size is 25,097,760  speedup is 3.72
# fatal: destination path '/content/dynamic_games_RL' already exists and is not an empty directory.
# [main 8b8d6b8] Upload all files from Colab
#  3 files changed, 3 insertions(+), 1 deletion(-)
#  create mode 100644 README.md
#  rewrite Untitled0.ipynb (75%)
#  delete mode 100644 "\341\204\211\341\205\263\341\204\217\341\205\263\341\204\205\341\205\265\341\206\253\341\204\211\341\205\243\341\206\272, 2025-07-10 22-09-07.png"
# From https://github.com/namwook0921/dynamic-games-RL
# ...

# %%
del /content
